# %% [markdown]
# 1)Draw Scatter Plot between SepalLengthCm and SepalWidthCm for "Iris.csv" file with proper labelling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Iris.csv')
plt.scatter(data['SepalLengthCm'],data['SepalWidthCm'])
plt.show()

# %% [markdown]
# 2) Draw Histogram of SepalLengthCm with proper labelling.

# %%
plt.hist(data['SepalLengthCm'],bins=5)
plt.show()

# %% [markdown]
# 3) Plot bar chart of Species.

# %%
data = pd.read_csv(r'/content/drive/MyDrive/Iris.csv')
data.head()
df = pd.DataFrame(data)
name = df['Species']
plt.bar(name,50,color ='maroon', width = 0.4)
plt.xlabel("Species")
plt.show()

# %% [markdown]
# 4) Count total null values for each column in this dataset.

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 5) 1) Print first 5 rows of SepalLengthCm. 2) Print from 5th row and onwards and entire column of Iris.csv dataset.

# %%
print(pd.read_csv('/content/drive/MyDrive/Iris.csv', nrows=5))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(pd.read_csv('/content/drive/MyDrive/Iris.csv', skiprows=range(1,5)))
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      5            5.0  ...           0.2     Iris-setosa
# 1      6            5.4  ...           0.4     Iris-setosa
# 2      7            4.6  ...           0.3     Iris-setosa
# 3      8            5.0  ...           0.2     Iris-setosa
# 4      9            4.4  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 141  146            6.7  ...           2.3  Iris-virginica
# 142  147            6.3  ...           1.9  Iris-virginica
# 143  148            6.5  ...           2.0  Iris-virginica
# 144  149            6.2  ...           2.3  Iris-virginica
# 145  150            5.9  ...           1.8  Iris-virginica
#
# [146 rows x 6 columns]
